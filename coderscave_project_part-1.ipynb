# %% [markdown]
# # project on data covid-19 analysis
#
# # task-1 of part-1 of the project
#
# # import the libraries

# %%
import pandas as pd
import numpy as nd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # loded the data setes

# %%
data=pd.read_csv(r"C:\Users\a\Downloads\COVID-19 India Statewise Vaccine Data.csv")

# %%
data
# Out:
#                                    State/UTs  Total Vaccination Doses  \
# 0                        Andaman and Nicobar                   629054
# 1                             Andhra Pradesh                 84147957
# 2                          Arunachal Pradesh                  1596166
# 3                                      Assam                 42998698
# 4                                      Bihar                119963226
# 5                                 Chandigarh                  2001114
# 6                               Chhattisgarh                 36927545
# 7   Dadra and Nagar Haveli and Daman and Diu                  1319914
# 8                                      Delhi                 30710281
# 9                                        Goa                  2572559
# 10                                   Gujarat                 98534412
# 11                                   Haryana                 40581317
# ...

# %% [markdown]
# # checking process the data set

# %%
data.head()
# Out:
#              State/UTs  Total Vaccination Doses    Dose 1    Dose 2  \
# 0  Andaman and Nicobar                   629054    311893    317161
# 1       Andhra Pradesh                 84147957  40624263  43523694
# 2    Arunachal Pradesh                  1596166    856732    739434
# 3                Assam                 42998698  22535419  20463279
# 4                Bihar                119963226  62590002  57373224
#
#    Population
# 0      399001
# 1    91702478
# 2     1711947
# 3    35998752
# 4   128500364

# %%
data.columns
# Out:
# Index(['State/UTs', 'Total Vaccination Doses', 'Dose 1', 'Dose 2',
#        'Population'],
#       dtype='object')

# %%
data.tail()
# Out:
#         State/UTs  Total Vaccination Doses     Dose 1     Dose 2  Population
# 31      Telangana                 58332610   29547155   28785455    38157311
# 32        Tripura                  4962881    2653391    2309490     4184959
# 33  Uttar Pradesh                299773777  153669397  146104380   231502578
# 34    Uttarakhand                 16068172    8164652    7903520    11700099
# 35    West Bengal                128418265   67232447   61185818   100896618

# %%
data.describe()
# Out:
#        Total Vaccination Doses        Dose 1        Dose 2    Population
# count             3.600000e+01  3.600000e+01  3.600000e+01  3.600000e+01
# mean              4.921979e+07  2.549133e+07  2.372846e+07  3.971861e+07
# std               6.252012e+07  3.226311e+07  3.029808e+07  5.050913e+07
# min               1.123780e+05  5.683100e+04  5.554700e+04  6.600100e+04
# 25%               1.906027e+06  1.042061e+06  8.696295e+05  1.695473e+06
# 50%               3.381891e+07  1.770508e+07  1.495231e+07  2.410088e+07
# 75%               8.740200e+07  4.278546e+07  4.417638e+07  6.979986e+07
# max               2.997738e+08  1.536694e+08  1.461044e+08  2.315026e+08

# %% [markdown]
# # checking the missing values

# %%
print("print any missing values?",data.isnull().values.any())
# Out:
# print any missing values? False

# %% [markdown]
# # check the null value of data

# %%
data.isnull()
# Out:
#     State/UTs  Total Vaccination Doses  Dose 1  Dose 2  Population
# 0       False                    False   False   False       False
# 1       False                    False   False   False       False
# 2       False                    False   False   False       False
# 3       False                    False   False   False       False
# 4       False                    False   False   False       False
# 5       False                    False   False   False       False
# 6       False                    False   False   False       False
# 7       False                    False   False   False       False
# 8       False                    False   False   False       False
# 9       False                    False   False   False       False
# 10      False                    False   False   False       False
# 11      False                    False   False   False       False
# 12      False                    False   False   False       False
# ...

# %%
data.isnull().sum()
# Out:
# State/UTs                  0
# Total Vaccination Doses    0
# Dose 1                     0
# Dose 2                     0
# Population                 0
# dtype: int64

# %%
data.columns
# Out:
# Index(['State/UTs', 'Total Vaccination Doses', 'Dose 1', 'Dose 2',
#        'Population'],
#       dtype='object')

# %% [markdown]
# # Relating the variables data setes

# %%
import seaborn as sns

# %%
import sys
sys.path
# Out:
# ['C:\\Users\\a',
#  'C:\\Users\\a\\AppData\\Local\\Programs\\Python\\Python310\\python310.zip',
#  'C:\\Users\\a\\AppData\\Local\\Programs\\Python\\Python310\\DLLs',
#  'C:\\Users\\a\\AppData\\Local\\Programs\\Python\\Python310\\lib',
#  'C:\\Users\\a\\AppData\\Local\\Programs\\Python\\Python310',
#  '',
#  'C:\\Users\\a\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages',
#  'C:\\Users\\a\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32',
#  'C:\\Users\\a\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\a\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\Pythonwin']

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
sns.relplot(x="Total Vaccination Doses", y="Population", data=data)

# %%
sns.relplot(x="Total Vaccination Doses", y="Dose 1", data=data)

# %%
sns.relplot(x="Total Vaccination Doses", y="Dose 2", data=data)

# %%
sns.relplot(x="Dose 1", y="Dose 2", data=data)

# %%
sns.relplot(x="Dose 1", y="Population", data=data)

# %%
sns.relplot(x="Dose 2", y="Population", data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x="Total Vaccination Doses", y="Population", kind="line", data=data)

# %%
sns.catplot(x="Total Vaccination Doses",y="Dose 1", data=data)

# %%
sns.catplot(x="Total Vaccination Doses",y="Dose 2", data=data)

# %%
sns.catplot(x="Total Vaccination Doses",y="Population", data=data)

# %%
sns.catplot(x="Population",y="Dose 1", data=data)

# %%
sns.catplot(x="Population",y="Dose 2", data=data)
